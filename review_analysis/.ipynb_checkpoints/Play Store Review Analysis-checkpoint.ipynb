# %% [markdown]
# # Review of Play Store reviews for current Dublin Bus application

# %%
# !pip3 install google-play-scraper
# Out:
# ...
#     100% |████████████████████████████████| 61kB 1.0MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for google-play-scraper ... done
#   Stored in directory: /home/faye/.cache/pip/wheels/e9/98/5a/917dd15a6f100d35a26c5f6f0ae99895ae861aff74fafa1b08
# Successfully built google-play-scraper
# ...

# %%
from google_play_scraper import Sort, reviews
import json
import spacy

# %% [markdown]
# ## 1 Star Reviews

# %%
onestar_result, onestar_continuation_token = reviews(
    'com.dublinbus.wearei3',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=300, # defaults to 100
    filter_score_with=1 # defaults to None(means all score)
)

# %%
for review in onestar_result:
    print(review["content"], end="\n\n")
# Out:
# This app is horrible. It supposedly gives real time information, but busses never arrive and simply disappear from the app. There is no point in receiving information if it cannot be trusted.
#
# Slow and not user friendly. Also, wrong times and ghost buses that don't come even though it says on the app. Dublin bus became a joke really and it was so good before. Not a single bus right so what's the point of it?
#
# The time not matching the bus timetable. You better read the review from us and try to find out a solution! Really didn't find any response from you. Really disappointed with Dublin not having such an easy app to help people.
#
# Doesnt work when you need it to, buses dont show up on the app, app crashes too frequently and its out of date as stops that arent in service anymore still show up
#
# Unreliability manifest in app form. Just missed an important appointment because of the utterly shambolic "real time."
#
# ...

# %% [markdown]
# ## 5 Star Reviews

# %%
fivestar_result, fivestar_continuation_token = reviews(
    'com.dublinbus.wearei3',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=300, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# %%
for review in fivestar_result:
    print(review["content"], end="\n\n")
# Out:
# This is my personal favourite of the Dublin Bus Apps, it shows real time based bus times for arrival and how long you will have to wait for the next bus, recommend this to everyone who needs a bus...
#
# The app itself is good. However the information provided to the app via Transport for Ireland is not always accurate. But I don't think this is a Dublin Bus issue.
#
# Gets it fairly right most of the time. But don't walk away from the stop if the bus hasn't arrived on spec.. give it a few minutes.
#
# Great app. Brilliantto know when your bus is coming.
#
# I think this is a good apo because you can see the time the bus is coming at and you can see all the Dublin buses. Recommended app.
#
# Very helpful app. Often more accurate than the bus stop display.
#
# Great app when busses are running at full or half capacity otherwise Health Care workers need to be in a car.
#
# Almost always accurate. Never miss s bus and no long waits. Has s map
#
# Dead handy for the time of your journey
# ...
